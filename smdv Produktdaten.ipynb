# %% [markdown]
# ## 1. Imports

# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 2. Load the csv file

# %%
fname = 'data/smdv_affilinet_products_1797_812673.csv'

# %%
df = pd.read_csv(fname, sep=';') #error_bad_lines=False
# Preview the first 5 lines of the loaded data 
df.head()
# Out:
#   ArtNumber                                              Title  \
# 0   R355621  Weidmüller BLZP 5.08HC/12/225B SN GN BX Leiter...
# 1   R355611  Weidmüller BLZP 5.08HC/16/225B SN GN BX Leiter...
# 2   R355601  Weidmüller S2CD-THR 3.50/12/90G 3.2SN BK BX Le...
# 3   R355491  Weidmüller SLS 5.08/07/180DF SN OR BX Leiterpl...
# 4   R355471  Weidmüller SLS 5.08/03/180DF SN OR BX Leiterpl...
#
#   Description_Short DisplayPrice  \
# 0               NaN   146.41 EUR
# 1               NaN   146.41 EUR
# 2               NaN   119.75 EUR
# 3               NaN   110.49 EUR
# 4               NaN    78.56 EUR
#
#                                              Img_url  \
# 0  https://asset.re-in.de/isa/160267/c1/-/de/WEID...
# 1  https://asset.re-in.de/isa/160267/c1/-/de/WEID...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
len(df)
# Out:
# 378288

# %% [markdown]
# ## 3. Rename columns & cleanup columns

# %%
#drop_cols = ['ProductCategoryName', 'CF_Energieeffizienzklasse', 'ProductCategoryID']

# %%
#filament_df.drop(drop_cols, axis=1, inplace=True)

# %%
df.Description_Short.fillna('', inplace = True)

# %%
df
# Out:
#        ArtNumber                                              Title  \
# 0        R355621  Weidmüller BLZP 5.08HC/12/225B SN GN BX Leiter...
# 1        R355611  Weidmüller BLZP 5.08HC/16/225B SN GN BX Leiter...
# 2        R355601  Weidmüller S2CD-THR 3.50/12/90G 3.2SN BK BX Le...
# 3        R355491  Weidmüller SLS 5.08/07/180DF SN OR BX Leiterpl...
# 4        R355471  Weidmüller SLS 5.08/03/180DF SN OR BX Leiterpl...
# ...          ...                                                ...
# 378283   X849011  VR COVER 10mm Headset Riemen Einlage Passend f...
# 378284   Q679592  HTC Vive Pro + Wireless Adapter Blau Virtual R...
# 378285   D690871  GAMEWAREZ RX Fire Gaming Sitzsack Schwarz, Orange
# 378286   W222551  Feuchtmann Meine Lieblingsknete - 4 x 150 gr. ...
# 378287   C683501                        02497-EU RC Mini Mario Kart
#
#                                         Description_Short DisplayPrice  \
# 0                                                           146.41 EUR
# ...

# %%
cols = list(filament_df.columns.values)
cols
# Out:
# ['EAN',
#  'Title',
#  'Brand',
#  'Manufacturer',
#  'ArtNumber',
#  'Description_Short',
#  'Description',
#  'DisplayPrice',
#  'Img_url',
#  'Deeplink1',
#  'ProductID']

# %%
ordered_cols = [
    'EAN',
    'Title',
    'Brand',
    'Manufacturer',
    'ArtNumber',
    'Description_Short',
    'Description',
    'DisplayPrice',
    'Img_url',
    'Deeplink1',
    'ProductID'
]

# %%
filament_df = filament_df[ordered_cols]

# %%
filament_df
# Out:
#                  EAN                                              Title  \
# 196747  8.809369e+12  Sindoh 3DP200ABK-R Filament ABS 1.75mm 600g Sc...
# 198894  4.016139e+12  Renkforce RF2000 Ersatzteil-Set Druckbett Pass...
# 199416  4.038816e+12  Snapmaker Thermoplastic Polyacetal Sheet Passe...
# 199878  6.970163e+12                    Shining SCSH-ESPR-2X 3D Scanner
# 199879  6.970163e+12                Shining EINSCAN-PRO 2X + 3D Scanner
# ...              ...                                                ...
# 261108  2.050003e+12  Renkforce Düse V2 0.3mm Passend für: RF1000, r...
# 261116  4.260395e+12  Flashforge Druckbettfolie Passend für: FlashFo...
# 261134  2.050003e+12  Renkforce Düse V2 0.8mm Passend für: RF1000, r...
# 261149  2.050003e+12  Renkforce Ersatzdichtung PTFE 4x1mm Passend fü...
# 261985  8.710364e+12               Dremel Filament PLA 1.75mm Blau 500g
#
#              Brand             Manufacturer ArtNumber  \
# ...

# %%
df.ProductCategoryID.value_counts()
# Out:
# 1496790     53363
# 1497112     51972
# 1496614     14594
# 1496607      9641
# 1497112      7198
#             ...
# 23323585        1
# 1496777         1
# 13936412        1
# 1497198         1
# 1496987         1
# Name: ProductCategoryID, Length: 1817, dtype: int64

# %% [markdown]
# ## 4. Create sub dataset for 3d printing equipment

# %%
cat_id = '21965829'  # 3d printing equipment

# %%
df_3d = df[df['ProductCategoryID']==cat_id].copy()

# %%
df_3d
# Out:
#        ArtNumber                                              Title  \
# 196747   D828051  Sindoh 3DP200ABK-R Filament ABS 1.75mm 600g Sc...
# 198894   W920321  Renkforce RF2000 Ersatzteil-Set Druckbett Pass...
# 199416   C059921  Snapmaker Thermoplastic Polyacetal Sheet Passe...
# 199878   A795432                    Shining SCSH-ESPR-2X 3D Scanner
# 199879   A795422                Shining EINSCAN-PRO 2X + 3D Scanner
# ...          ...                                                ...
# 261108   A085261  Renkforce Düse V2 0.3mm Passend für: RF1000, r...
# 261116   R062431  Flashforge Druckbettfolie Passend für: FlashFo...
# 261134   A085171  Renkforce Düse V2 0.8mm Passend für: RF1000, r...
# 261149   A067761  Renkforce Ersatzdichtung PTFE 4x1mm Passend fü...
# 261985   Y179471               Dremel Filament PLA 1.75mm Blau 500g
#
#                                         Description_Short DisplayPrice  \
# 196747  Sindoh ABS Refill Filament Mit dem umweltfreun...    34.95 EUR
# ...

# %%
df_3d.describe
# Out:
# <bound method NDFrame.describe of        ArtNumber                                              Title  \
# 196747   D828051  Sindoh 3DP200ABK-R Filament ABS 1.75mm 600g Sc...
# 198894   W920321  Renkforce RF2000 Ersatzteil-Set Druckbett Pass...
# 199416   C059921  Snapmaker Thermoplastic Polyacetal Sheet Passe...
# 199878   A795432                    Shining SCSH-ESPR-2X 3D Scanner
# 199879   A795422                Shining EINSCAN-PRO 2X + 3D Scanner
# ...          ...                                                ...
# 261108   A085261  Renkforce Düse V2 0.3mm Passend für: RF1000, r...
# 261116   R062431  Flashforge Druckbettfolie Passend für: FlashFo...
# 261134   A085171  Renkforce Düse V2 0.8mm Passend für: RF1000, r...
# 261149   A067761  Renkforce Ersatzdichtung PTFE 4x1mm Passend fü...
# 261985   Y179471               Dremel Filament PLA 1.75mm Blau 500g
#
#                                         Description_Short DisplayPrice  \
# ...

# %%
filament_df = df_3d[df_3d['Description_Short'].str.contains('Filament')]

# %%
small_df
# Out:
#                  EAN                                              Title  \
# 196747  8.809369e+12  Sindoh 3DP200ABK-R Filament ABS 1.75mm 600g Sc...
# 202834  4.053199e+12           Renkforce Filament PLA 2.85mm Orange 1kg
# 204867  4.053199e+12           Renkforce Filament PLA 1.75mm Orange 1kg
# 204868  4.053199e+12            Renkforce Filament PETG 1.75mm Weiß 1kg
# 204869  4.053199e+12             Renkforce Filament PETG 2.85mm Rot 1kg
# ...              ...                                                ...
# 260594  5.410330e+12  Velleman PLA175L07 Filament PLA nachleuchtend ...
# 260595  5.410330e+12   Velleman PLA175H07 Filament PLA 1.75mm 750g Grau
# 260596  5.410330e+12   Velleman PLA175G07 Filament PLA 1.75mm 750g Grün
# 260940  6.409709e+11  Proto-Pasta SSP11701 Filament PLA 1.75mm 125g ...
# 261985  8.710364e+12               Dremel Filament PLA 1.75mm Blau 500g
#
#               Brand   Manufacturer ArtNumber  \
# 196747       Sindoh    3DP200ABK-R   D828051
# ...

# %%
small_df['Brand'].value_counts()
# Out:
# Renkforce         92
# Polymaker         69
# Innofil 3D        42
# Formfutura        33
# Velleman          30
# Ultimaker         24
# Verbatim          21
# XYZprinting       17
# German RepRap     11
# Dremel            10
# 3D Simo            5
# Basf Innofil3D     3
# REC                2
# Proto-Pasta        2
# Polaroid           2
# DuPont             1
# Formlabs           1
# Creality           1
# igus               1
# Sindoh             1
# Name: Brand, dtype: int64

# %%
filament_df['Brand'].value_counts()
# Out:
# Renkforce                  152
# Polymaker                   69
# Velleman                    57
# Innofil 3D                  42
# Formfutura                  33
# Ultimaker                   32
# XYZprinting                 29
# Verbatim                    21
# Dremel                      13
# German RepRap               11
# BCN3D                        9
# BUILDTAK                     8
# 3D Simo                      7
# Formlabs                     6
# snapmaker                    4
# Shining                      3
# PL NoName                    3
# Flashforge                   3
# No Name (foreign brand)      3
# Basf Innofil3D               3
# Hanser Verlag                3
# Polaroid                     2
# Zortrax                      2
# SCAN in a BOX                2
# DAVID                        2
# Proto-Pasta                  2
# REC                          2
# 3D Solex                     2
# Matter and Form              1
# bq                           1
# ...
