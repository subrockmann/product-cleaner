# %%
import pandas as pd

# %%
fname = 'data/smdv_affilinet_products_1797_812673.csv'

# %%
df = pd.read_csv(fname, sep=';') #error_bad_lines=False
# Preview the first 5 lines of the loaded data 
df.head()
# Out:
# C:\Users\susbr\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   ArtNumber                                              Title  \
# 0   R355621  Weidmüller BLZP 5.08HC/12/225B SN GN BX Leiter...
# 1   R355611  Weidmüller BLZP 5.08HC/16/225B SN GN BX Leiter...
# 2   R355601  Weidmüller S2CD-THR 3.50/12/90G 3.2SN BK BX Le...
# 3   R355491  Weidmüller SLS 5.08/07/180DF SN OR BX Leiterpl...
# 4   R355471  Weidmüller SLS 5.08/03/180DF SN OR BX Leiterpl...
#
#   Description_Short DisplayPrice  \
# 0               NaN   146.41 EUR
# 1               NaN   146.41 EUR
# 2               NaN   119.75 EUR
# 3               NaN   110.49 EUR
# 4               NaN    78.56 EUR
#
#                                              Img_url  \
# ...

# %%
len(df)
# Out:
# 378288

# %%
filament = df[df['Title'].str.contains('Fila')]

# %%
cat_id = '21965829'

# %%
print (filament)
# Out:
#        ArtNumber                                              Title  \
# 4311     Y804601   Igus I180-PF-0175-0250 Filament 1.75mm 250g Weiß
# 4312     X790861  Ultimaker Filament PP (Polypropylen) 2.85mm Na...
# 4313     S103951  Velleman PLA175U07 Filament PLA 1.75mm 750g Du...
# 5690     S568831  Ultimaker PLA - M0751 Black 750 - 211399 Filam...
# 7031     Q562972  Polymaker 70158 Filament PolyMax PLA 2.85mm 75...
# ...          ...                                                ...
# 375818   W945351  Basf Innofil3D PLA-0035A075 Filament PLA 1.75m...
# 375819   W945311  Basf Innofil3D PLA-0024A075 Filament PLA 1.75m...
# 375820   W945281  Basf Innofil3D PLA-0021A075 Filament PLA 1.75m...
# 375998   Q192252  Creality CR-10S Pro 3D Drucker Bausatz geeigne...
# 376335   X413771  Ultimaker 1644 Filament CPE+ chemisch beständi...
#
#                                         Description_Short DisplayPrice  \
# 4311    igus® präsentiert weltweit erstes Tribo-Filame...    47.95 EUR
# ...

# %%
filament_df = df[df['ProductCategoryID']==cat_id].copy()

# %%
filament_df.head()
# Out:
#        ArtNumber                                              Title  \
# 196747   D828051  Sindoh 3DP200ABK-R Filament ABS 1.75mm 600g Sc...
# 198894   W920321  Renkforce RF2000 Ersatzteil-Set Druckbett Pass...
# 199416   C059921  Snapmaker Thermoplastic Polyacetal Sheet Passe...
# 199878   A795432                    Shining SCSH-ESPR-2X 3D Scanner
# 199879   A795422                Shining EINSCAN-PRO 2X + 3D Scanner
#
#                                         Description_Short DisplayPrice  \
# 196747  Sindoh ABS Refill Filament Mit dem umweltfreun...    34.95 EUR
# 198894                                                NaN   138.82 EUR
# 199416  Drei Stück POM-Blatt. Polyoxymethylen (POM), a...    10.99 EUR
# 199878  Tragbarer und flexibler 3D-Scanner für hochprä...  5944.99 EUR
# 199879  Tragbarer und flexibler 3D-Scanner für hochprä...  7484.99 EUR
#
#                                                   Img_url  \
# 196747  https://asset.re-in.de/isa/160267/c1/-/de/1763...
# ...

# %%
len(filament_df)
# Out:
# 532

# %%
drop_cols = ['ProductCategoryName', 'CF_Energieeffizienzklasse']

# %%
filament_df.drop(drop_cols, axis=1, inplace=True)

# %%
cols = list(filament_df.columns.values)

# %%
cols
# Out:
# ['ArtNumber',
#  'Title',
#  'Description_Short',
#  'DisplayPrice',
#  'Img_url',
#  'Deeplink1',
#  'ProductCategoryID',
#  'Manufacturer',
#  'EAN',
#  'ProductID',
#  'Description',
#  'Brand']

# %%
ordered_cols = [
    'EAN',
    'Title',
    'Brand',
    'Manufacturer',
    'ArtNumber',
    'Description_Short',
    'Description',
     'DisplayPrice',
    'Img_url',
    'Deeplink1',
    'ProductCategoryID',
    'ProductID'
]

# %%
filament_df = filament_df[ordered_cols]

# %%
filament_df
# Out:
#                  EAN                                              Title  \
# 196747  8.809369e+12  Sindoh 3DP200ABK-R Filament ABS 1.75mm 600g Sc...
# 198894  4.016139e+12  Renkforce RF2000 Ersatzteil-Set Druckbett Pass...
# 199416  4.038816e+12  Snapmaker Thermoplastic Polyacetal Sheet Passe...
# 199878  6.970163e+12                    Shining SCSH-ESPR-2X 3D Scanner
# 199879  6.970163e+12                Shining EINSCAN-PRO 2X + 3D Scanner
# ...              ...                                                ...
# 261108  2.050003e+12  Renkforce Düse V2 0.3mm Passend für: RF1000, r...
# 261116  4.260395e+12  Flashforge Druckbettfolie Passend für: FlashFo...
# 261134  2.050003e+12  Renkforce Düse V2 0.8mm Passend für: RF1000, r...
# 261149  2.050003e+12  Renkforce Ersatzdichtung PTFE 4x1mm Passend fü...
# 261985  8.710364e+12               Dremel Filament PLA 1.75mm Blau 500g
#
#              Brand             Manufacturer ArtNumber  \
# ...

# %%
small_df = filament_df[filament_df['Title'].str.contains('Fila')]

# %%
small_df
# Out:
#                  EAN                                              Title  \
# 196747  8.809369e+12  Sindoh 3DP200ABK-R Filament ABS 1.75mm 600g Sc...
# 202834  4.053199e+12           Renkforce Filament PLA 2.85mm Orange 1kg
# 204867  4.053199e+12           Renkforce Filament PLA 1.75mm Orange 1kg
# 204868  4.053199e+12            Renkforce Filament PETG 1.75mm Weiß 1kg
# 204869  4.053199e+12             Renkforce Filament PETG 2.85mm Rot 1kg
# ...              ...                                                ...
# 260594  5.410330e+12  Velleman PLA175L07 Filament PLA nachleuchtend ...
# 260595  5.410330e+12   Velleman PLA175H07 Filament PLA 1.75mm 750g Grau
# 260596  5.410330e+12   Velleman PLA175G07 Filament PLA 1.75mm 750g Grün
# 260940  6.409709e+11  Proto-Pasta SSP11701 Filament PLA 1.75mm 125g ...
# 261985  8.710364e+12               Dremel Filament PLA 1.75mm Blau 500g
#
#               Brand   Manufacturer ArtNumber  \
# 196747       Sindoh    3DP200ABK-R   D828051
# ...

# %%
small_df['Brand'].value_counts()
# Out:
# Renkforce         92
# Polymaker         69
# Innofil 3D        42
# Formfutura        33
# Velleman          30
# Ultimaker         24
# Verbatim          21
# XYZprinting       17
# German RepRap     11
# Dremel            10
# 3D Simo            5
# Basf Innofil3D     3
# REC                2
# Polaroid           2
# Proto-Pasta        2
# Formlabs           1
# DuPont             1
# igus               1
# Sindoh             1
# Creality           1
# Name: Brand, dtype: int64

# %%
filament_df['Brand'].value_counts()
# Out:
# Renkforce                  152
# Polymaker                   69
# Velleman                    57
# Innofil 3D                  42
# Formfutura                  33
# Ultimaker                   32
# XYZprinting                 29
# Verbatim                    21
# Dremel                      13
# German RepRap               11
# BCN3D                        9
# BUILDTAK                     8
# 3D Simo                      7
# Formlabs                     6
# snapmaker                    4
# Basf Innofil3D               3
# Flashforge                   3
# Hanser Verlag                3
# No Name (foreign brand)      3
# PL NoName                    3
# Shining                      3
# 3D Solex                     2
# Proto-Pasta                  2
# SCAN in a BOX                2
# Polaroid                     2
# Zortrax                      2
# DAVID                        2
# REC                          2
# igus                         1
# DuPont                       1
# ...
