# %%
import pandas as pd

# %%
fname = 'reichelt_affilinet_products_1752_812673.csv'

# %%
df = pd.read_csv(fname, sep=';') #error_bad_lines=False
# Preview the first 5 lines of the loaded data 
df.head()
# Out:
# C:\Users\susbr\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          ArtNumber                                              Title  \
# 0       EL KO ADR4  EL KO ADR4 - Abdeckrahmen - 4-fach, HK05, arct...
# 1     EATON 242541  EATON 242541 - Leitungsschutzschalter, Char. C...
# 2     DELOCK 90434  DELOCK 90434 - Netzwerkkarte, PCI Express, 10 ...
# 3  TOS M203K0320EA  TOS M203K0320EA - MicroSDHC-Speicherkarte M203...
# 4    5W METALL 1,0  5W METALL 1,0 - Drahtwiderstand, axial, 5 W, 1...
#
#                                    Description_Short DisplayPrice  \
# 0  4-fach Abdeckrahmen für die Serie OBJEKT 2005 ...     7.50 EUR
# 1  Leitungsschutzschalter 3-polig + Neutralleiter...    26.50 EUR
# 2  Diese PCI Express Karte von IOI bietet einen N...   399.95 EUR
# 3  Das Handy haben Sie immer dabei – und Ihre sch...     5.95 EUR
# 4  VISHAY Drahtwiderstände im Aluminiumgehäuse Se...     3.40 EUR
#
#                                              Img_url  \
# 0  https://cdn-reichelt.de/bilder/web/xxl_ws/D700...
# 1  https://cdn-reichelt.de/bilder/web/xxl_ws/D700...
# 2  https://cdn-reichelt.de/bilder/web/xxl_ws/E910...
# 3  https://cdn-reichelt.de/bilder/web/xxl_ws/E910...
# 4  https://cdn-reichelt.de/bilder/web/xxl_ws/B400...
#
#                                            Deeplink1  ProductCategoryID  \
# 0  https://partners.webmasterplan.com/click.asp?r...           13687538
# 1  https://partners.webmasterplan.com/click.asp?r...           13686787
# 2  https://partners.webmasterplan.com/click.asp?r...           13686950
# 3  https://partners.webmasterplan.com/click.asp?r...           13687754
# 4  https://partners.webmasterplan.com/click.asp?r...           27821893
#
#                                  ProductCategoryName Manufacturer  \
# 0  Messtechnik und Werkstattbedarf > Elektromater...         KOPP
# 1  Messtechnik und Werkstattbedarf > Elektromater...        EATON
# 2  PC-Technik > Netzwerktechnik > aktive Komponen...       DELOCK
# 3  PC-Technik > Speicherkarten / USB-Sticks > SD-...      TOSHIBA
# 4  Bauelemente, passiv > Widerstände > Bedrahtete...       VISHAY
#
#             EAN  ...  CF_Versand_Vorkasse CF_Versand_PayPal  CF_ISBN  \
# 0  4.008224e+12  ...                  NaN               NaN      NaN
# 1  4.015082e+12  ...                  NaN               NaN      NaN
# 2  4.043620e+12  ...                  NaN               NaN      NaN
# 3  4.047999e+12  ...                  NaN               NaN      NaN
# 4           NaN  ...                  NaN               NaN      NaN
#
#    CF_Gewicht  CF_EEK  CF_Lieferzeit              CF_Verfügbarkeit CF_Color  \
# 0         NaN     NaN   1-2 Werktage                      ab Lager      NaN
# 1         NaN     NaN   1-2 Werktage                      ab Lager      NaN
# 2         NaN     NaN   1-2 Werktage                      ab Lager      NaN
# 3         NaN     NaN   1-2 Werktage  begrenzte Stückzahl, lagernd      NaN
# 4         NaN     NaN   1-2 Werktage                      ab Lager      NaN
#
#   CF_Size CF_Gender
# 0     NaN       NaN
# 1     NaN       NaN
# 2     NaN       NaN
# 3     NaN       NaN
# 4     NaN       NaN
#
# [5 rows x 23 columns]

# %%
len(df)
# Out:
# 100516

# %%
filament = df[df['Title'].str.contains('Fila')]

# %%
filament
# Out:
#               ArtNumber                                              Title  \
# 26     PLA REC 2,85 NAT  PLA REC 2,85 NAT - PLA Filament - natur - 2,85...
# 48        OSR 075132894  OSR 075132894 - LED-Lampe STAR E14, 4 W, 470 l...
# 162        INNOFIL 0013  INNOFIL 0013 - PLA Filament - schoko braun - 2...
# 1571   SCHI LF023871312  SCHI LF023871312 - LED-Lampe E14, 4 W, 250 lm,...
# 1572    SCHI L022366037  SCHI L022366037 - LED-Lampe G9, 3 W, 260 lm, 2...
# ...                 ...                                                ...
# 99348     INNOFIL 20933  INNOFIL 20933 - Tough PLA Filament - schwarz -...
# 99616         CF 555747  CF 555747 - NGEN FLEX Filament - dunkelgrau - ...
# 99619     OSR 075114241  OSR 075114241 - LED-Lampe STAR+ E14, 5 W, 600 ...
# 99620         CF 553514    CF 553514 - XT Filament - rot - 2,85 mm - 750 g
# 99772   ABS REC 2,85 SW  ABS REC 2,85 SW - ABS Filament - schwarz - 2,8...
#
#                                        Description_Short DisplayPrice  \
# 26     Beim PLA-Filament von REC können Sie sich auf ...    13.95 EUR
# 48     Energiesparend und langlebig - LED-Beleuchtung...     8.99 EUR
# 162    Innofil 3D - Das innovative 3D-Drucker Filamen...    22.95 EUR
# 1571   LED-Leuchtmittel von Schiefer Lighting - immer...     8.55 EUR
# 1572   LED-Leuchtmittel von Schiefer Lighting - immer...     6.45 EUR
# ...                                                  ...          ...
# 99348  Mit dem Innofil3D Pro1 Filament bietet der hol...    34.95 EUR
# 99616  nGen_FLEX ist ein neues Elastomermaterial, das...    39.95 EUR
# 99619  Klare Lampen mit innovativer LED-Filament-Tech...     8.80 EUR
# 99620  Die Farbe ist ein wichtiger Aspekt für 3D-Druc...    24.95 EUR
# 99772  Beim ABS Filament von REC können Sie sich auf ...    14.95 EUR
#
#                                                  Img_url  \
# 26     https://cdn-reichelt.de/bilder/web/xxl_ws/E400...
# 48     https://cdn-reichelt.de/bilder/web/xxl_ws/L700...
# 162    https://cdn-reichelt.de/bilder/web/xxl_ws/E400...
# 1571   https://cdn-reichelt.de/bilder/web/xxl_ws/L700...
# 1572   https://cdn-reichelt.de/bilder/web/xxl_ws/L700...
# ...                                                  ...
# 99348  https://cdn-reichelt.de/bilder/web/xxl_ws/E400...
# 99616  https://cdn-reichelt.de/bilder/web/xxl_ws/EB00...
# 99619  https://cdn-reichelt.de/bilder/web/xxl_ws/L700...
# 99620  https://cdn-reichelt.de/bilder/web/xxl_ws/E400...
# 99772  https://cdn-reichelt.de/bilder/web/xxl_ws/E400...
#
#                                                Deeplink1  ProductCategoryID  \
# 26     https://partners.webmasterplan.com/click.asp?r...           25309485
# 48     https://partners.webmasterplan.com/click.asp?r...           28823436
# 162    https://partners.webmasterplan.com/click.asp?r...           25309485
# 1571   https://partners.webmasterplan.com/click.asp?r...           28823436
# 1572   https://partners.webmasterplan.com/click.asp?r...           28823434
# ...                                                  ...                ...
# 99348  https://partners.webmasterplan.com/click.asp?r...           25309482
# 99616  https://partners.webmasterplan.com/click.asp?r...           25309485
# 99619  https://partners.webmasterplan.com/click.asp?r...           28823436
# 99620  https://partners.webmasterplan.com/click.asp?r...           25309485
# 99772  https://partners.webmasterplan.com/click.asp?r...           25309485
#
#                                      ProductCategoryName       Manufacturer  \
# 26     PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...                REC
# 48                Lichttechnik > LED-Lampen > Sockel E14              OSRAM
# 162    PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...          INNOFIL3D
# 1571              Lichttechnik > LED-Lampen > Sockel E14  SCHIEFER LIGHTING
# 1572               Lichttechnik > LED-Lampen > Sockel G9  SCHIEFER LIGHTING
# ...                                                  ...                ...
# 99348  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...          INNOFIL3D
# 99616  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...          COLORFABB
# 99619             Lichttechnik > LED-Lampen > Sockel E14              OSRAM
# 99620  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...          COLORFABB
# 99772  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...                REC
#
#                 EAN  ...  CF_Versand_Vorkasse CF_Versand_PayPal  CF_ISBN  \
# 26     4.627096e+12  ...                  NaN               NaN      NaN
# 48     4.058075e+12  ...                  NaN               NaN      NaN
# 162    8.718970e+12  ...                  NaN               NaN      NaN
# 1571   8.718739e+12  ...                  NaN               NaN      NaN
# 1572   8.718739e+12  ...                  NaN               NaN      NaN
# ...             ...  ...                  ...               ...      ...
# 99348  8.718970e+12  ...                  NaN               NaN      NaN
# 99616  8.719034e+12  ...                  NaN               NaN      NaN
# 99619  4.058075e+12  ...                  NaN               NaN      NaN
# 99620  8.719034e+12  ...                  NaN               NaN      NaN
# 99772  4.627096e+12  ...                  NaN               NaN      NaN
#
#        CF_Gewicht  CF_EEK  CF_Lieferzeit  CF_Verfügbarkeit CF_Color CF_Size  \
# 26            NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 48            NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 162           NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 1571          NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 1572          NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# ...           ...     ...            ...               ...      ...     ...
# 99348         NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 99616         NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 99619         NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 99620         NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 99772         NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
#
#       CF_Gender
# 26          NaN
# 48          NaN
# 162         NaN
# 1571        NaN
# 1572        NaN
# ...         ...
# 99348       NaN
# 99616       NaN
# 99619       NaN
# 99620       NaN
# 99772       NaN
#
# [777 rows x 23 columns]

# %%
filament['ProductCategoryName'].value_counts()
# Out:
# PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D Drucker > Filamente für 3D-Drucker (1,75 mm)      234
# PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D Drucker > Filamente für 3D Drucker (2,85/3 mm)    210
# Lichttechnik > LED-Lampen > Sockel E27                                                                                       170
# Lichttechnik > LED-Lampen > Sockel E14                                                                                       133
# Haus- und Sicherheitstechnik > Home-Automation / Smart Home > Connected Light > Connected Light - Lampen/Leuchtmittel         18
# Lichttechnik > LED-Lampen > Sonstige Sockel                                                                                    7
# Lichttechnik > LED-Lampen > Sockel G9                                                                                          2
# Bauelemente, mechanisch > Schalter > Drucktaster / -schalter > Druckschalter-System                                            1
# PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Ersatzteile und Zubehör für 3D-Drucker                                        1
# PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > 3D-Drucker                                                                    1
# Name: ProductCategoryName, dtype: int64

# %%
filament[filament['ProductCategoryName'].str.contains('(2,85/3 mm)')]
# Out:
#               ArtNumber                                              Title  \
# 26     PLA REC 2,85 NAT  PLA REC 2,85 NAT - PLA Filament - natur - 2,85...
# 162        INNOFIL 0013  INNOFIL 0013 - PLA Filament - schoko braun - 2...
# 3191      INNOFIL 11231  INNOFIL 11231 - ZPCTG Filament - schwarz - 1,7...
# 3316      INNOFIL 11569  INNOFIL 11569 - TPU 80A LF Filament - transpar...
# 4917      INNOFIL 23279  INNOFIL 23279 - lebensmittelechtes Filament - ...
# ...                 ...                                                ...
# 99345     INNOFIL 20964  INNOFIL 20964 - Tough PLA Filament - natur wei...
# 99347     INNOFIL 20940  INNOFIL 20940 - Tough PLA Filament - schwarz -...
# 99616         CF 555747  CF 555747 - NGEN FLEX Filament - dunkelgrau - ...
# 99620         CF 553514    CF 553514 - XT Filament - rot - 2,85 mm - 750 g
# 99772   ABS REC 2,85 SW  ABS REC 2,85 SW - ABS Filament - schwarz - 2,8...
#
#                                        Description_Short DisplayPrice  \
# 26     Beim PLA-Filament von REC können Sie sich auf ...    13.95 EUR
# 162    Innofil 3D - Das innovative 3D-Drucker Filamen...    22.95 EUR
# 3191   Ultrafuse Z PCTG ist ein ESD sicheres Filament...    91.95 EUR
# 3316   Der Artikelzusatz ´´LF´´ steht für ´´Low Frict...   101.95 EUR
# 4917   EPR PET wurde von Innofil entwickelt, ist lebe...    29.95 EUR
# ...                                                  ...          ...
# 99345  Mit dem Innofil3D Pro1 Filament bietet der hol...    34.95 EUR
# 99347  Mit dem Innofil3D Pro1 Filament bietet der hol...    34.95 EUR
# 99616  nGen_FLEX ist ein neues Elastomermaterial, das...    39.95 EUR
# 99620  Die Farbe ist ein wichtiger Aspekt für 3D-Druc...    24.95 EUR
# 99772  Beim ABS Filament von REC können Sie sich auf ...    14.95 EUR
#
#                                                  Img_url  \
# 26     https://cdn-reichelt.de/bilder/web/xxl_ws/E400...
# 162    https://cdn-reichelt.de/bilder/web/xxl_ws/E400...
# 3191   https://cdn-reichelt.de/bilder/web/xxl_ws/E400...
# 3316   https://cdn-reichelt.de/bilder/web/xxl_ws/E400...
# 4917   https://cdn-reichelt.de/bilder/web/xxl_ws/E400...
# ...                                                  ...
# 99345  https://cdn-reichelt.de/bilder/web/xxl_ws/E400...
# 99347  https://cdn-reichelt.de/bilder/web/xxl_ws/E400...
# 99616  https://cdn-reichelt.de/bilder/web/xxl_ws/EB00...
# 99620  https://cdn-reichelt.de/bilder/web/xxl_ws/E400...
# 99772  https://cdn-reichelt.de/bilder/web/xxl_ws/E400...
#
#                                                Deeplink1  ProductCategoryID  \
# 26     https://partners.webmasterplan.com/click.asp?r...           25309485
# 162    https://partners.webmasterplan.com/click.asp?r...           25309485
# 3191   https://partners.webmasterplan.com/click.asp?r...           25309485
# 3316   https://partners.webmasterplan.com/click.asp?r...           25309485
# 4917   https://partners.webmasterplan.com/click.asp?r...           25309485
# ...                                                  ...                ...
# 99345  https://partners.webmasterplan.com/click.asp?r...           25309485
# 99347  https://partners.webmasterplan.com/click.asp?r...           25309485
# 99616  https://partners.webmasterplan.com/click.asp?r...           25309485
# 99620  https://partners.webmasterplan.com/click.asp?r...           25309485
# 99772  https://partners.webmasterplan.com/click.asp?r...           25309485
#
#                                      ProductCategoryName Manufacturer  \
# 26     PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...          REC
# 162    PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...    INNOFIL3D
# 3191   PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...    INNOFIL3D
# 3316   PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...    INNOFIL3D
# 4917   PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...    INNOFIL3D
# ...                                                  ...          ...
# 99345  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...    INNOFIL3D
# 99347  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...    INNOFIL3D
# 99616  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...    COLORFABB
# 99620  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...    COLORFABB
# 99772  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck...          REC
#
#                 EAN  ...  CF_Versand_Vorkasse CF_Versand_PayPal  CF_ISBN  \
# 26     4.627096e+12  ...                  NaN               NaN      NaN
# 162    8.718970e+12  ...                  NaN               NaN      NaN
# 3191   5.060666e+12  ...                  NaN               NaN      NaN
# 3316   5.060666e+12  ...                  NaN               NaN      NaN
# 4917   8.718970e+12  ...                  NaN               NaN      NaN
# ...             ...  ...                  ...               ...      ...
# 99345  8.718970e+12  ...                  NaN               NaN      NaN
# 99347  8.718970e+12  ...                  NaN               NaN      NaN
# 99616  8.719034e+12  ...                  NaN               NaN      NaN
# 99620  8.719034e+12  ...                  NaN               NaN      NaN
# 99772  4.627096e+12  ...                  NaN               NaN      NaN
#
#        CF_Gewicht  CF_EEK  CF_Lieferzeit  CF_Verfügbarkeit CF_Color CF_Size  \
# 26            NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 162           NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 3191          NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 3316          NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 4917          NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# ...           ...     ...            ...               ...      ...     ...
# 99345         NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 99347         NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 99616         NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 99620         NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
# 99772         NaN     NaN   1-2 Werktage          ab Lager      NaN     NaN
#
#       CF_Gender
# 26          NaN
# 162         NaN
# 3191        NaN
# 3316        NaN
# 4917        NaN
# ...         ...
# 99345       NaN
# 99347       NaN
# 99616       NaN
# 99620       NaN
# 99772       NaN
#
# [210 rows x 23 columns]

# %%
cat_175 = 25309482
cat_3 = 25309485

# %%
df_3mm = filament[filament['ProductCategoryID'] == cat_3]

# %%
df_3mm
# Out:
#               ArtNumber  \
# 26     PLA REC 2,85 NAT
# 162        INNOFIL 0013
# 3191      INNOFIL 11231
# 3316      INNOFIL 11569
# 4917      INNOFIL 23279
# ...                 ...
# 99345     INNOFIL 20964
# 99347     INNOFIL 20940
# 99616         CF 555747
# 99620         CF 553514
# 99772   ABS REC 2,85 SW
#
#                                                                      Title  \
# 26               PLA REC 2,85 NAT - PLA Filament - natur - 2,85 mm - 750 g
# 162                   INNOFIL 0013 - PLA Filament - schoko braun - 2,85 mm
# 3191            INNOFIL 11231 - ZPCTG Filament - schwarz - 1,75 mm - 750 g
# 3316   INNOFIL 11569 - TPU 80A LF Filament - transparent - 2,85 mm - 750 g
# 4917          INNOFIL 23279 - lebensmittelechtes Filament - weiß - 2,85 mm
# ...                                                                    ...
# 99345    INNOFIL 20964 - Tough PLA Filament - natur weiß - 2,85 mm - 750 g
# 99347       INNOFIL 20940 - Tough PLA Filament - schwarz - 2,85 mm - 750 g
# 99616        CF 555747 - NGEN FLEX Filament - dunkelgrau - 2,85 mm - 650 g
# 99620                      CF 553514 - XT Filament - rot - 2,85 mm - 750 g
# 99772           ABS REC 2,85 SW - ABS Filament - schwarz - 2,85 mm - 750 g
#
#                                                                      Description_Short  \
# 26     Beim PLA-Filament von REC können Sie sich auf europäische Topqualität verlas...
# 162    Innofil 3D - Das innovative 3D-Drucker Filament! Beim Innofil3D PLA Filament...
# 3191   Ultrafuse Z PCTG ist ein ESD sicheres Filament, welches für spezielle Anwend...
# 3316   Der Artikelzusatz ´´LF´´ steht für ´´Low Friction´´, also eine geringe Reibu...
# 4917   EPR PET wurde von Innofil entwickelt, ist lebensmittelecht und während der V...
# ...                                                                                ...
# 99345  Mit dem Innofil3D Pro1 Filament bietet der holländische Filament-Hersteller ...
# 99347  Mit dem Innofil3D Pro1 Filament bietet der holländische Filament-Hersteller ...
# 99616  nGen_FLEX ist ein neues Elastomermaterial, das zu unserem bestehenden Sortim...
# 99620  Die Farbe ist ein wichtiger Aspekt für 3D-Druck-Projekte. Daher hat colorFab...
# 99772  Beim ABS Filament von REC können Sie sich auf europäische Topqualität verlas...
#
#       DisplayPrice  \
# 26       13.95 EUR
# 162      22.95 EUR
# 3191     91.95 EUR
# 3316    101.95 EUR
# 4917     29.95 EUR
# ...            ...
# 99345    34.95 EUR
# 99347    34.95 EUR
# 99616    39.95 EUR
# 99620    24.95 EUR
# 99772    14.95 EUR
#
#                                                                          Img_url  \
# 26        https://cdn-reichelt.de/bilder/web/xxl_ws/E400/REC_PLA_2.85_nat_01.png
# 162           https://cdn-reichelt.de/bilder/web/xxl_ws/E400/INNOFIL_0013_01.png
# 3191         https://cdn-reichelt.de/bilder/web/xxl_ws/E400/INNOFIL_11231_01.png
# 3316         https://cdn-reichelt.de/bilder/web/xxl_ws/E400/INNOFIL_11569_01.png
# 4917         https://cdn-reichelt.de/bilder/web/xxl_ws/E400/INNOFIL_23071_01.png
# ...                                                                          ...
# 99345        https://cdn-reichelt.de/bilder/web/xxl_ws/E400/INNOFIL_20964_01.png
# 99347        https://cdn-reichelt.de/bilder/web/xxl_ws/E400/INNOFIL_20940_01.png
# 99616  https://cdn-reichelt.de/bilder/web/xxl_ws/EB00/CF_555730_CF_555747_01.png
# 99620            https://cdn-reichelt.de/bilder/web/xxl_ws/E400/CF_553507_01.png
# 99772      https://cdn-reichelt.de/bilder/web/xxl_ws/E400/REC_ABS_2.85_sw_01.png
#
#                                                                              Deeplink1  \
# 26     https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 162    https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 3191   https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 3316   https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 4917   https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# ...                                                                                ...
# 99345  https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 99347  https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 99616  https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 99620  https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 99772  https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
#
#        ProductCategoryID  \
# 26              25309485
# 162             25309485
# 3191            25309485
# 3316            25309485
# 4917            25309485
# ...                  ...
# 99345           25309485
# 99347           25309485
# 99616           25309485
# 99620           25309485
# 99772           25309485
#
#                                                                    ProductCategoryName  \
# 26     PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 162    PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 3191   PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 3316   PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 4917   PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# ...                                                                                ...
# 99345  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 99347  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 99616  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 99620  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 99772  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
#
#       Manufacturer           EAN  ...  CF_Versand_Vorkasse CF_Versand_PayPal  \
# 26             REC  4.627096e+12  ...                  NaN               NaN
# 162      INNOFIL3D  8.718970e+12  ...                  NaN               NaN
# 3191     INNOFIL3D  5.060666e+12  ...                  NaN               NaN
# 3316     INNOFIL3D  5.060666e+12  ...                  NaN               NaN
# 4917     INNOFIL3D  8.718970e+12  ...                  NaN               NaN
# ...            ...           ...  ...                  ...               ...
# 99345    INNOFIL3D  8.718970e+12  ...                  NaN               NaN
# 99347    INNOFIL3D  8.718970e+12  ...                  NaN               NaN
# 99616    COLORFABB  8.719034e+12  ...                  NaN               NaN
# 99620    COLORFABB  8.719034e+12  ...                  NaN               NaN
# 99772          REC  4.627096e+12  ...                  NaN               NaN
#
#        CF_ISBN  CF_Gewicht  CF_EEK  CF_Lieferzeit  CF_Verfügbarkeit CF_Color  \
# 26         NaN         NaN     NaN   1-2 Werktage          ab Lager      NaN
# 162        NaN         NaN     NaN   1-2 Werktage          ab Lager      NaN
# 3191       NaN         NaN     NaN   1-2 Werktage          ab Lager      NaN
# 3316       NaN         NaN     NaN   1-2 Werktage          ab Lager      NaN
# 4917       NaN         NaN     NaN   1-2 Werktage          ab Lager      NaN
# ...        ...         ...     ...            ...               ...      ...
# 99345      NaN         NaN     NaN   1-2 Werktage          ab Lager      NaN
# 99347      NaN         NaN     NaN   1-2 Werktage          ab Lager      NaN
# 99616      NaN         NaN     NaN   1-2 Werktage          ab Lager      NaN
# 99620      NaN         NaN     NaN   1-2 Werktage          ab Lager      NaN
# 99772      NaN         NaN     NaN   1-2 Werktage          ab Lager      NaN
#
#       CF_Size CF_Gender
# 26        NaN       NaN
# 162       NaN       NaN
# 3191      NaN       NaN
# 3316      NaN       NaN
# 4917      NaN       NaN
# ...       ...       ...
# 99345     NaN       NaN
# 99347     NaN       NaN
# 99616     NaN       NaN
# 99620     NaN       NaN
# 99772     NaN       NaN
#
# [210 rows x 23 columns]

# %%
title_3mm = df_3mm.Title.str.split('-',expand=True)
#df['V'].str.split('-',expand=True)

# %%
combined_df = pd.concat([df_3mm, title_3mm], axis=1)

# %%
combined_df
# Out:
#               ArtNumber  \
# 26     PLA REC 2,85 NAT
# 162        INNOFIL 0013
# 3191      INNOFIL 11231
# 3316      INNOFIL 11569
# 4917      INNOFIL 23279
# ...                 ...
# 99345     INNOFIL 20964
# 99347     INNOFIL 20940
# 99616         CF 555747
# 99620         CF 553514
# 99772   ABS REC 2,85 SW
#
#                                                                      Title  \
# 26               PLA REC 2,85 NAT - PLA Filament - natur - 2,85 mm - 750 g
# 162                   INNOFIL 0013 - PLA Filament - schoko braun - 2,85 mm
# 3191            INNOFIL 11231 - ZPCTG Filament - schwarz - 1,75 mm - 750 g
# 3316   INNOFIL 11569 - TPU 80A LF Filament - transparent - 2,85 mm - 750 g
# 4917          INNOFIL 23279 - lebensmittelechtes Filament - weiß - 2,85 mm
# ...                                                                    ...
# 99345    INNOFIL 20964 - Tough PLA Filament - natur weiß - 2,85 mm - 750 g
# 99347       INNOFIL 20940 - Tough PLA Filament - schwarz - 2,85 mm - 750 g
# 99616        CF 555747 - NGEN FLEX Filament - dunkelgrau - 2,85 mm - 650 g
# 99620                      CF 553514 - XT Filament - rot - 2,85 mm - 750 g
# 99772           ABS REC 2,85 SW - ABS Filament - schwarz - 2,85 mm - 750 g
#
#                                                                      Description_Short  \
# 26     Beim PLA-Filament von REC können Sie sich auf europäische Topqualität verlas...
# 162    Innofil 3D - Das innovative 3D-Drucker Filament! Beim Innofil3D PLA Filament...
# 3191   Ultrafuse Z PCTG ist ein ESD sicheres Filament, welches für spezielle Anwend...
# 3316   Der Artikelzusatz ´´LF´´ steht für ´´Low Friction´´, also eine geringe Reibu...
# 4917   EPR PET wurde von Innofil entwickelt, ist lebensmittelecht und während der V...
# ...                                                                                ...
# 99345  Mit dem Innofil3D Pro1 Filament bietet der holländische Filament-Hersteller ...
# 99347  Mit dem Innofil3D Pro1 Filament bietet der holländische Filament-Hersteller ...
# 99616  nGen_FLEX ist ein neues Elastomermaterial, das zu unserem bestehenden Sortim...
# 99620  Die Farbe ist ein wichtiger Aspekt für 3D-Druck-Projekte. Daher hat colorFab...
# 99772  Beim ABS Filament von REC können Sie sich auf europäische Topqualität verlas...
#
#       DisplayPrice  \
# 26       13.95 EUR
# 162      22.95 EUR
# 3191     91.95 EUR
# 3316    101.95 EUR
# 4917     29.95 EUR
# ...            ...
# 99345    34.95 EUR
# 99347    34.95 EUR
# 99616    39.95 EUR
# 99620    24.95 EUR
# 99772    14.95 EUR
#
#                                                                          Img_url  \
# 26        https://cdn-reichelt.de/bilder/web/xxl_ws/E400/REC_PLA_2.85_nat_01.png
# 162           https://cdn-reichelt.de/bilder/web/xxl_ws/E400/INNOFIL_0013_01.png
# 3191         https://cdn-reichelt.de/bilder/web/xxl_ws/E400/INNOFIL_11231_01.png
# 3316         https://cdn-reichelt.de/bilder/web/xxl_ws/E400/INNOFIL_11569_01.png
# 4917         https://cdn-reichelt.de/bilder/web/xxl_ws/E400/INNOFIL_23071_01.png
# ...                                                                          ...
# 99345        https://cdn-reichelt.de/bilder/web/xxl_ws/E400/INNOFIL_20964_01.png
# 99347        https://cdn-reichelt.de/bilder/web/xxl_ws/E400/INNOFIL_20940_01.png
# 99616  https://cdn-reichelt.de/bilder/web/xxl_ws/EB00/CF_555730_CF_555747_01.png
# 99620            https://cdn-reichelt.de/bilder/web/xxl_ws/E400/CF_553507_01.png
# 99772      https://cdn-reichelt.de/bilder/web/xxl_ws/E400/REC_ABS_2.85_sw_01.png
#
#                                                                              Deeplink1  \
# 26     https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 162    https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 3191   https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 3316   https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 4917   https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# ...                                                                                ...
# 99345  https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 99347  https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 99616  https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 99620  https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
# 99772  https://partners.webmasterplan.com/click.asp?ref=812673&site=8948&type=text&...
#
#        ProductCategoryID  \
# 26              25309485
# 162             25309485
# 3191            25309485
# 3316            25309485
# 4917            25309485
# ...                  ...
# 99345           25309485
# 99347           25309485
# 99616           25309485
# 99620           25309485
# 99772           25309485
#
#                                                                    ProductCategoryName  \
# 26     PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 162    PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 3191   PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 3316   PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 4917   PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# ...                                                                                ...
# 99345  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 99347  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 99616  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 99620  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
# 99772  PC-Technik > IT-Peripherie/-Zubehör > 3D Druck > Verbrauchsmaterial für 3D D...
#
#       Manufacturer           EAN  ...  CF_Verfügbarkeit CF_Color  CF_Size  \
# 26             REC  4.627096e+12  ...          ab Lager      NaN      NaN
# 162      INNOFIL3D  8.718970e+12  ...          ab Lager      NaN      NaN
# 3191     INNOFIL3D  5.060666e+12  ...          ab Lager      NaN      NaN
# 3316     INNOFIL3D  5.060666e+12  ...          ab Lager      NaN      NaN
# 4917     INNOFIL3D  8.718970e+12  ...          ab Lager      NaN      NaN
# ...            ...           ...  ...               ...      ...      ...
# 99345    INNOFIL3D  8.718970e+12  ...          ab Lager      NaN      NaN
# 99347    INNOFIL3D  8.718970e+12  ...          ab Lager      NaN      NaN
# 99616    COLORFABB  8.719034e+12  ...          ab Lager      NaN      NaN
# 99620    COLORFABB  8.719034e+12  ...          ab Lager      NaN      NaN
# 99772          REC  4.627096e+12  ...          ab Lager      NaN      NaN
#
#        CF_Gender                  0                              1  \
# 26           NaN  PLA REC 2,85 NAT                   PLA Filament
# 162          NaN      INNOFIL 0013                   PLA Filament
# 3191         NaN     INNOFIL 11231                 ZPCTG Filament
# 3316         NaN     INNOFIL 11569            TPU 80A LF Filament
# 4917         NaN     INNOFIL 23279    lebensmittelechtes Filament
# ...          ...                ...                            ...
# 99345        NaN     INNOFIL 20964             Tough PLA Filament
# 99347        NaN     INNOFIL 20940             Tough PLA Filament
# 99616        NaN         CF 555747             NGEN FLEX Filament
# 99620        NaN         CF 553514                    XT Filament
# 99772        NaN   ABS REC 2,85 SW                   ABS Filament
#
#                     2          3       4     5
# 26             natur    2,85 mm    750 g  None
# 162     schoko braun     2,85 mm    None  None
# 3191         schwarz    1,75 mm    750 g  None
# 3316     transparent    2,85 mm    750 g  None
# 4917            weiß     2,85 mm    None  None
# ...               ...        ...     ...   ...
# 99345     natur weiß    2,85 mm    750 g  None
# 99347        schwarz    2,85 mm    750 g  None
# 99616     dunkelgrau    2,85 mm    650 g  None
# 99620            rot    2,85 mm    750 g  None
# 99772        schwarz    2,85 mm    750 g  None
#
# [210 rows x 29 columns]

# %%
title_3mm
# Out:
#                        0                              1               2  \
# 26     PLA REC 2,85 NAT                   PLA Filament           natur
# 162        INNOFIL 0013                   PLA Filament    schoko braun
# 3191      INNOFIL 11231                 ZPCTG Filament         schwarz
# 3316      INNOFIL 11569            TPU 80A LF Filament     transparent
# 4917      INNOFIL 23279    lebensmittelechtes Filament            weiß
# ...                  ...                            ...             ...
# 99345     INNOFIL 20964             Tough PLA Filament      natur weiß
# 99347     INNOFIL 20940             Tough PLA Filament         schwarz
# 99616         CF 555747             NGEN FLEX Filament      dunkelgrau
# 99620         CF 553514                    XT Filament             rot
# 99772   ABS REC 2,85 SW                   ABS Filament         schwarz
#
#                3       4     5
# 26      2,85 mm    750 g  None
# 162      2,85 mm    None  None
# 3191    1,75 mm    750 g  None
# 3316    2,85 mm    750 g  None
# 4917     2,85 mm    None  None
# ...          ...     ...   ...
# 99345   2,85 mm    750 g  None
# 99347   2,85 mm    750 g  None
# 99616   2,85 mm    650 g  None
# 99620   2,85 mm    750 g  None
# 99772   2,85 mm    750 g  None
#
# [210 rows x 6 columns]

# %%
pd.set_option('max_colwidth', 80)

# %%
df_3mm[['ArtNumber', 'Manufacturer', 'Title', 'Description_Short']]
# Out:
#               ArtNumber Manufacturer  \
# 26     PLA REC 2,85 NAT          REC
# 162        INNOFIL 0013    INNOFIL3D
# 3191      INNOFIL 11231    INNOFIL3D
# 3316      INNOFIL 11569    INNOFIL3D
# 4917      INNOFIL 23279    INNOFIL3D
# ...                 ...          ...
# 99345     INNOFIL 20964    INNOFIL3D
# 99347     INNOFIL 20940    INNOFIL3D
# 99616         CF 555747    COLORFABB
# 99620         CF 553514    COLORFABB
# 99772   ABS REC 2,85 SW          REC
#
#                                                                      Title  \
# 26               PLA REC 2,85 NAT - PLA Filament - natur - 2,85 mm - 750 g
# 162                   INNOFIL 0013 - PLA Filament - schoko braun - 2,85 mm
# 3191            INNOFIL 11231 - ZPCTG Filament - schwarz - 1,75 mm - 750 g
# 3316   INNOFIL 11569 - TPU 80A LF Filament - transparent - 2,85 mm - 750 g
# 4917          INNOFIL 23279 - lebensmittelechtes Filament - weiß - 2,85 mm
# ...                                                                    ...
# 99345    INNOFIL 20964 - Tough PLA Filament - natur weiß - 2,85 mm - 750 g
# 99347       INNOFIL 20940 - Tough PLA Filament - schwarz - 2,85 mm - 750 g
# 99616        CF 555747 - NGEN FLEX Filament - dunkelgrau - 2,85 mm - 650 g
# 99620                      CF 553514 - XT Filament - rot - 2,85 mm - 750 g
# 99772           ABS REC 2,85 SW - ABS Filament - schwarz - 2,85 mm - 750 g
#
#                                                                      Description_Short
# 26     Beim PLA-Filament von REC können Sie sich auf europäische Topqualität verlas...
# 162    Innofil 3D - Das innovative 3D-Drucker Filament! Beim Innofil3D PLA Filament...
# 3191   Ultrafuse Z PCTG ist ein ESD sicheres Filament, welches für spezielle Anwend...
# 3316   Der Artikelzusatz ´´LF´´ steht für ´´Low Friction´´, also eine geringe Reibu...
# 4917   EPR PET wurde von Innofil entwickelt, ist lebensmittelecht und während der V...
# ...                                                                                ...
# 99345  Mit dem Innofil3D Pro1 Filament bietet der holländische Filament-Hersteller ...
# 99347  Mit dem Innofil3D Pro1 Filament bietet der holländische Filament-Hersteller ...
# 99616  nGen_FLEX ist ein neues Elastomermaterial, das zu unserem bestehenden Sortim...
# 99620  Die Farbe ist ein wichtiger Aspekt für 3D-Druck-Projekte. Daher hat colorFab...
# 99772  Beim ABS Filament von REC können Sie sich auf europäische Topqualität verlas...
#
# [210 rows x 4 columns]

# %%
filament_df = df[df['ProductCategoryID']==cat_id].copy()

# %%
filament_df.head()
# Out:
#        ArtNumber                                              Title  \
# 196747   D828051  Sindoh 3DP200ABK-R Filament ABS 1.75mm 600g Sc...
# 198894   W920321  Renkforce RF2000 Ersatzteil-Set Druckbett Pass...
# 199416   C059921  Snapmaker Thermoplastic Polyacetal Sheet Passe...
# 199878   A795432                    Shining SCSH-ESPR-2X 3D Scanner
# 199879   A795422                Shining EINSCAN-PRO 2X + 3D Scanner
#
#                                         Description_Short DisplayPrice  \
# 196747  Sindoh ABS Refill Filament Mit dem umweltfreun...    34.95 EUR
# 198894                                                NaN   138.82 EUR
# 199416  Drei Stück POM-Blatt. Polyoxymethylen (POM), a...    10.99 EUR
# 199878  Tragbarer und flexibler 3D-Scanner für hochprä...  5944.99 EUR
# 199879  Tragbarer und flexibler 3D-Scanner für hochprä...  7484.99 EUR
#
#                                                   Img_url  \
# 196747  https://asset.re-in.de/isa/160267/c1/-/de/1763...
# 198894  https://asset.re-in.de/isa/160267/c1/-/de/1413...
# 199416  https://asset.re-in.de/isa/160267/c1/-/de/0018...
# 199878  https://asset.re-in.de/isa/160267/c1/-/de/0022...
# 199879  https://asset.re-in.de/isa/160267/c1/-/de/0022...
#
#                                                 Deeplink1 ProductCategoryID  \
# 196747  https://partners.webmasterplan.com/click.asp?r...          21965829
# 198894  https://partners.webmasterplan.com/click.asp?r...          21965829
# 199416  https://partners.webmasterplan.com/click.asp?r...          21965829
# 199878  https://partners.webmasterplan.com/click.asp?r...          21965829
# 199879  https://partners.webmasterplan.com/click.asp?r...          21965829
#
#                                       ProductCategoryName  \
# 196747  Schule & Büro > Büro > Bürogeräte > Drucker > ...
# 198894  Schule & Büro > Büro > Bürogeräte > Drucker > ...
# 199416  Schule & Büro > Büro > Bürogeräte > Drucker > ...
# 199878  Schule & Büro > Büro > Bürogeräte > Drucker > ...
# 199879  Schule & Büro > Büro > Bürogeräte > Drucker > ...
#
#                Manufacturer           EAN   ProductID  \
# 196747          3DP200ABK-R  8.809369e+12  1952327732
# 198894  RF2000 SET2 DR-BETT  4.016139e+12    19709910
# 199416   SNAP_CNC_POM_33031  4.038816e+12  1973801149
# 199878         SCSH-ESPR-2X  6.970163e+12  1977193456
# 199879     EINSCAN-PRO 2X +  6.970163e+12  1977193810
#
#                                               Description      Brand  \
# 196747  Sindoh ABS Refill Filament Mit dem umweltfreun...     Sindoh
# 198894                                                NaN  Renkforce
# 199416  Drei Stück POM-Blatt. Polyoxymethylen (POM), a...  snapmaker
# 199878  Tragbarer und flexibler 3D-Scanner für hochprä...    Shining
# 199879  Tragbarer und flexibler 3D-Scanner für hochprä...    Shining
#
#        CF_Energieeffizienzklasse
# 196747                       NaN
# 198894                       NaN
# 199416                       NaN
# 199878                       NaN
# 199879                       NaN

# %%
len(filament_df)
# Out:
# 532

# %%
drop_cols = ['ProductCategoryName', 'CF_Energieeffizienzklasse']

# %%
filament_df.drop(drop_cols, axis=1, inplace=True)

# %%
cols = list(filament_df.columns.values)

# %%
cols
# Out:
# ['ArtNumber',
#  'Title',
#  'Description_Short',
#  'DisplayPrice',
#  'Img_url',
#  'Deeplink1',
#  'ProductCategoryID',
#  'Manufacturer',
#  'EAN',
#  'ProductID',
#  'Description',
#  'Brand']

# %%
ordered_cols = [
    'EAN',
    'Title',
    'Brand',
    'Manufacturer',
    'ArtNumber',
    'Description_Short',
    'Description',
     'DisplayPrice',
    'Img_url',
    'Deeplink1',
    'ProductCategoryID',
    'ProductID'
]

# %%
filament_df = filament_df[ordered_cols]

# %%
filament_df
# Out:
#                  EAN                                              Title  \
# 196747  8.809369e+12  Sindoh 3DP200ABK-R Filament ABS 1.75mm 600g Sc...
# 198894  4.016139e+12  Renkforce RF2000 Ersatzteil-Set Druckbett Pass...
# 199416  4.038816e+12  Snapmaker Thermoplastic Polyacetal Sheet Passe...
# 199878  6.970163e+12                    Shining SCSH-ESPR-2X 3D Scanner
# 199879  6.970163e+12                Shining EINSCAN-PRO 2X + 3D Scanner
# ...              ...                                                ...
# 261108  2.050003e+12  Renkforce Düse V2 0.3mm Passend für: RF1000, r...
# 261116  4.260395e+12  Flashforge Druckbettfolie Passend für: FlashFo...
# 261134  2.050003e+12  Renkforce Düse V2 0.8mm Passend für: RF1000, r...
# 261149  2.050003e+12  Renkforce Ersatzdichtung PTFE 4x1mm Passend fü...
# 261985  8.710364e+12               Dremel Filament PLA 1.75mm Blau 500g
#
#              Brand             Manufacturer ArtNumber  \
# 196747      Sindoh              3DP200ABK-R   D828051
# 198894   Renkforce      RF2000 SET2 DR-BETT   W920321
# 199416   snapmaker       SNAP_CNC_POM_33031   C059921
# 199878     Shining             SCSH-ESPR-2X   A795432
# 199879     Shining         EINSCAN-PRO 2X +   A795422
# ...            ...                      ...       ...
# 261108   Renkforce  I851-349 Düse V2 0.3 mm   A085261
# 261116  Flashforge             60.001170001   R062431
# 261134   Renkforce                 I851-348   A085171
# 261149   Renkforce         Joint PTFE 4x1mm   A067761
# 261985      Dremel               26153D06JA   Y179471
#
#                                         Description_Short  \
# 196747  Sindoh ABS Refill Filament Mit dem umweltfreun...
# 198894                                                NaN
# 199416  Drei Stück POM-Blatt. Polyoxymethylen (POM), a...
# 199878  Tragbarer und flexibler 3D-Scanner für hochprä...
# 199879  Tragbarer und flexibler 3D-Scanner für hochprä...
# ...                                                   ...
# 261108                                                NaN
# 261116  Diese Folie wird auf das Druckbett des Drucker...
# 261134                                                NaN
# 261149                                                NaN
# 261985                                                NaN
#
#                                               Description DisplayPrice  \
# 196747  Sindoh ABS Refill Filament Mit dem umweltfreun...    34.95 EUR
# 198894                                                NaN   138.82 EUR
# 199416  Drei Stück POM-Blatt. Polyoxymethylen (POM), a...    10.99 EUR
# 199878  Tragbarer und flexibler 3D-Scanner für hochprä...  5944.99 EUR
# 199879  Tragbarer und flexibler 3D-Scanner für hochprä...  7484.99 EUR
# ...                                                   ...          ...
# 261108                                                NaN     6.09 EUR
# 261116  Diese Folie wird auf das Druckbett des Drucker...     9.90 EUR
# 261134                                                NaN     6.09 EUR
# 261149                                                NaN     0.99 EUR
# 261985                                                NaN    17.99 EUR
#
#                                                   Img_url  \
# 196747  https://asset.re-in.de/isa/160267/c1/-/de/1763...
# 198894  https://asset.re-in.de/isa/160267/c1/-/de/1413...
# 199416  https://asset.re-in.de/isa/160267/c1/-/de/0018...
# 199878  https://asset.re-in.de/isa/160267/c1/-/de/0022...
# 199879  https://asset.re-in.de/isa/160267/c1/-/de/0022...
# ...                                                   ...
# 261108  https://asset.re-in.de/isa/160267/c1/-/de/1296...
# 261116  https://asset.re-in.de/isa/160267/c1/-/de/FLAS...
# 261134  https://asset.re-in.de/isa/160267/c1/-/de/1296...
# 261149  https://asset.re-in.de/isa/160267/c1/-/de/1298...
# 261985  https://asset.re-in.de/isa/160267/c1/-/de/1340...
#
#                                                 Deeplink1 ProductCategoryID  \
# 196747  https://partners.webmasterplan.com/click.asp?r...          21965829
# 198894  https://partners.webmasterplan.com/click.asp?r...          21965829
# 199416  https://partners.webmasterplan.com/click.asp?r...          21965829
# 199878  https://partners.webmasterplan.com/click.asp?r...          21965829
# 199879  https://partners.webmasterplan.com/click.asp?r...          21965829
# ...                                                   ...               ...
# 261108  https://partners.webmasterplan.com/click.asp?r...          21965829
# 261116  https://partners.webmasterplan.com/click.asp?r...          21965829
# 261134  https://partners.webmasterplan.com/click.asp?r...          21965829
# 261149  https://partners.webmasterplan.com/click.asp?r...          21965829
# 261985  https://partners.webmasterplan.com/click.asp?r...          21965829
#
#          ProductID
# 196747  1952327732
# 198894    19709910
# 199416  1973801149
# 199878  1977193456
# 199879  1977193810
# ...            ...
# 261108   666077372
# 261116   666117489
# 261134   666163488
# 261149   666191940
# 261985   667284618
#
# [532 rows x 12 columns]

# %%
small_df = filament_df[filament_df['Title'].str.contains('Fila')]

# %%
small_df
# Out:
#                  EAN                                              Title  \
# 196747  8.809369e+12  Sindoh 3DP200ABK-R Filament ABS 1.75mm 600g Sc...
# 202834  4.053199e+12           Renkforce Filament PLA 2.85mm Orange 1kg
# 204867  4.053199e+12           Renkforce Filament PLA 1.75mm Orange 1kg
# 204868  4.053199e+12            Renkforce Filament PETG 1.75mm Weiß 1kg
# 204869  4.053199e+12             Renkforce Filament PETG 2.85mm Rot 1kg
# ...              ...                                                ...
# 260594  5.410330e+12  Velleman PLA175L07 Filament PLA nachleuchtend ...
# 260595  5.410330e+12   Velleman PLA175H07 Filament PLA 1.75mm 750g Grau
# 260596  5.410330e+12   Velleman PLA175G07 Filament PLA 1.75mm 750g Grün
# 260940  6.409709e+11  Proto-Pasta SSP11701 Filament PLA 1.75mm 125g ...
# 261985  8.710364e+12               Dremel Filament PLA 1.75mm Blau 500g
#
#               Brand   Manufacturer ArtNumber  \
# 196747       Sindoh    3DP200ABK-R   D828051
# 202834    Renkforce  01.04.01.1211   S291921
# 204867    Renkforce  01.04.01.1111   S565051
# 204868    Renkforce  01.04.18.1102   S562511
# 204869    Renkforce  01.04.18.1204   S292641
# ...             ...            ...       ...
# 260594     Velleman      PLA175L07   S101041
# 260595     Velleman      PLA175H07   S101031
# 260596     Velleman      PLA175G07   S101011
# 260940  Proto-Pasta       SSP11701   R062491
# 261985       Dremel     26153D06JA   Y179471
#
#                                         Description_Short  \
# 196747  Sindoh ABS Refill Filament Mit dem umweltfreun...
# 202834  Für hoch aufgelöste Prototypen PLA ist das ide...
# 204867  Für hoch aufgelöste Prototypen PLA ist das ide...
# 204868  Maschinell gewickelt Die maschinelle Wicklung ...
# 204869  Maschinell gewickelt Die maschinelle Wicklung ...
# ...                                                   ...
# 260594  PLA ist hart, leicht zu verwenden und ideal fü...
# 260595  PLA ist hart, leicht zu verwenden und ideal fü...
# 260596  PLA ist hart, leicht zu verwenden und ideal fü...
# 260940  Proto-Pasta PLA aus rostfreiem Stahl ist ein F...
# 261985                                                NaN
#
#                                               Description DisplayPrice  \
# 196747  Sindoh ABS Refill Filament Mit dem umweltfreun...    34.95 EUR
# 202834  Für hoch aufgelöste Prototypen PLA ist das ide...    29.99 EUR
# 204867  Für hoch aufgelöste Prototypen PLA ist das ide...    29.99 EUR
# 204868  Maschinell gewickelt Die maschinelle Wicklung ...    29.99 EUR
# 204869  Maschinell gewickelt Die maschinelle Wicklung ...    29.99 EUR
# ...                                                   ...          ...
# 260594  PLA ist hart, leicht zu verwenden und ideal fü...    24.90 EUR
# 260595  PLA ist hart, leicht zu verwenden und ideal fü...    19.90 EUR
# 260596  PLA ist hart, leicht zu verwenden und ideal fü...    19.99 EUR
# 260940  Proto-Pasta PLA aus rostfreiem Stahl ist ein F...    21.90 EUR
# 261985                                                NaN    17.99 EUR
#
#                                                   Img_url  \
# 196747  https://asset.re-in.de/isa/160267/c1/-/de/1763...
# 202834  https://asset.re-in.de/isa/160267/c1/-/de/1531...
# 204867  https://asset.re-in.de/isa/160267/c1/-/de/1528...
# 204868  https://asset.re-in.de/isa/160267/c1/-/de/1528...
# 204869  https://asset.re-in.de/isa/160267/c1/-/de/1528...
# ...                                                   ...
# 260594  https://asset.re-in.de/isa/160267/c1/-/de/1549...
# 260595  https://asset.re-in.de/isa/160267/c1/-/de/1549...
# 260596  https://asset.re-in.de/isa/160267/c1/-/de/1549...
# 260940  https://asset.re-in.de/isa/160267/c1/-/de/0019...
# 261985  https://asset.re-in.de/isa/160267/c1/-/de/1340...
#
#                                                 Deeplink1 ProductCategoryID  \
# 196747  https://partners.webmasterplan.com/click.asp?r...          21965829
# 202834  https://partners.webmasterplan.com/click.asp?r...          21965829
# 204867  https://partners.webmasterplan.com/click.asp?r...          21965829
# 204868  https://partners.webmasterplan.com/click.asp?r...          21965829
# 204869  https://partners.webmasterplan.com/click.asp?r...          21965829
# ...                                                   ...               ...
# 260594  https://partners.webmasterplan.com/click.asp?r...          21965829
# 260595  https://partners.webmasterplan.com/click.asp?r...          21965829
# 260596  https://partners.webmasterplan.com/click.asp?r...          21965829
# 260940  https://partners.webmasterplan.com/click.asp?r...          21965829
# 261985  https://partners.webmasterplan.com/click.asp?r...          21965829
#
#          ProductID
# 196747  1952327732
# 202834  1987659216
# 204867  1989590043
# 204868  1989590050
# 204869  1989590076
# ...            ...
# 260594   665025629
# 260595   665025700
# 260596   665025918
# 260940   665731458
# 261985   667284618
#
# [368 rows x 12 columns]

# %%
small_df['Brand'].value_counts()
# Out:
# Renkforce         92
# Polymaker         69
# Innofil 3D        42
# Formfutura        33
# Velleman          30
# Ultimaker         24
# Verbatim          21
# XYZprinting       17
# German RepRap     11
# Dremel            10
# 3D Simo            5
# Basf Innofil3D     3
# REC                2
# Polaroid           2
# Proto-Pasta        2
# Formlabs           1
# DuPont             1
# igus               1
# Sindoh             1
# Creality           1
# Name: Brand, dtype: int64

# %%
filament_df['Brand'].value_counts()
# Out:
# Renkforce                  152
# Polymaker                   69
# Velleman                    57
# Innofil 3D                  42
# Formfutura                  33
# Ultimaker                   32
# XYZprinting                 29
# Verbatim                    21
# Dremel                      13
# German RepRap               11
# BCN3D                        9
# BUILDTAK                     8
# 3D Simo                      7
# Formlabs                     6
# snapmaker                    4
# Basf Innofil3D               3
# Flashforge                   3
# Hanser Verlag                3
# No Name (foreign brand)      3
# PL NoName                    3
# Shining                      3
# 3D Solex                     2
# Proto-Pasta                  2
# SCAN in a BOX                2
# Polaroid                     2
# Zortrax                      2
# DAVID                        2
# REC                          2
# igus                         1
# DuPont                       1
# bq                           1
# Sindoh                       1
# Matter and Form              1
# APRINTAPRO                   1
# Creality                     1
# Name: Brand, dtype: int64
